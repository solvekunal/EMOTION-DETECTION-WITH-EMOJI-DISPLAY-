# %% [markdown]
# # EMOTION DETECTION WITH EMOJI DISPLAY ON LIVE VIDEO FEED. THIS WORKS

# %%
import cv2
from fer import FER

# Initialize emotion detector
emotion_detector = FER()

# Load emoji images separately
happy_emoji = cv2.imread(r'E:\jupyter_notebook\Pictures\happy2.png', cv2.IMREAD_UNCHANGED)
sad_emoji = cv2.imread(r'E:\jupyter_notebook\Pictures\sad2png.png', cv2.IMREAD_UNCHANGED)
angry_emoji = cv2.imread(r'E:\jupyter_notebook\Pictures\angry2.png', cv2.IMREAD_UNCHANGED)
neutral_emoji = cv2.imread(r'E:\jupyter_notebook\Pictures\neutral.png', cv2.IMREAD_UNCHANGED)

# Function to resize emoji if loaded
def resize_emoji(emoji, size):
    if emoji is not None:
        return cv2.resize(emoji, size, interpolation=cv2.INTER_AREA)
    else:
        print("Failed to load emoji, cannot resize.")
        return None

# Resize emojis to a smaller size (e.g., 50x50 pixels)
emoji_size = (80, 80)
happy_emoji = resize_emoji(happy_emoji, emoji_size)
sad_emoji = resize_emoji(sad_emoji, emoji_size)
angry_emoji = resize_emoji(angry_emoji, emoji_size)
neutral_emoji = resize_emoji(neutral_emoji, emoji_size)

# Start video capture
cap = cv2.VideoCapture(0)

# Get the width and height of the video capture
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Define the codec and create VideoWriter object
fourcc = cv2.VideoWriter_fourcc(*'XVID')  # You can use 'MJPG' or 'XVID'
output_filename = 'output_video_emoji.avi'
out = cv2.VideoWriter(output_filename, fourcc, 20.0, (frame_width, frame_height))

# Set the probability threshold
probability_threshold = 0.5

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Detect emotions
    emotions = emotion_detector.detect_emotions(frame)
    if emotions:
        emotion_data = emotions[0]['emotions']
        total_prob = sum(emotion_data.values())
        
        if total_prob > 0:
            normalized_emotions = {emotion: prob / total_prob for emotion, prob in emotion_data.items()}
            #print("Normalized Emotions:", normalized_emotions)  # Debugging line
            
            top_emotion, top_probability = max(normalized_emotions.items(), key=lambda item: item[1])
            #print(f"Top Emotion: {top_emotion}, Probability: {top_probability:.2f}")  # Debugging line

            if top_probability > probability_threshold:
                x, y, w, h = emotions[0]['box']
                cv2.rectangle(frame, (x, y), (x + w, y + h), (255, 0, 0), 2)

                emotion_text = f"{top_emotion}: {top_probability:.2f}"
                cv2.putText(frame, emotion_text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)

                # Determine which emoji to display
                if top_emotion == 'happy':
                    emoji_img = happy_emoji
                elif top_emotion == 'sad':
                    emoji_img = sad_emoji
                elif top_emotion == 'angry':
                    emoji_img = angry_emoji
                elif top_emotion == 'neutral':
                    emoji_img = neutral_emoji
                else:
                    emoji_img = None  # No valid emoji

                if emoji_img is not None:
                    emoji_height, emoji_width = emoji_img.shape[:2]
                    emoji_x = x + w // 2 - emoji_width // 2
                    emoji_y = y - emoji_height - 10

                    print(f"Emoji position: ({emoji_x}, {emoji_y}), Shape: {emoji_img.shape}")  # Debugging line

                    if emoji_y > 0 and emoji_x >= 0:  # Ensure emoji fits in frame
                        if emoji_img.shape[2] == 4:  # PNG with alpha channel
                            emoji_mask = emoji_img[:, :, 3] / 255.0
                            for c in range(0, 3):
                                frame[emoji_y:emoji_y + emoji_height, emoji_x:emoji_x + emoji_width, c] = (
                                    emoji_mask * emoji_img[:, :, c] +
                                    (1 - emoji_mask) * frame[emoji_y:emoji_y + emoji_height, emoji_x:emoji_x + emoji_width, c]
                                )
                        else:  # JPG without alpha channel
                            frame[emoji_y:emoji_y + emoji_height, emoji_x:emoji_x + emoji_width] = emoji_img[:emoji_height, :emoji_width]

    # Write the frame to the video file
    out.write(frame)

    cv2.imshow('Emotion Detection', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release everything
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# Emoji position: (283, 45), Shape: (80, 80, 3)
# Emoji position: (282, 44), Shape: (80, 80, 3)
# Emoji position: (283, 44), Shape: (80, 80, 3)
# Emoji position: (284, 43), Shape: (80, 80, 3)
# Emoji position: (284, 42), Shape: (80, 80, 3)
# Emoji position: (284, 45), Shape: (80, 80, 3)
# Emoji position: (285, 42), Shape: (80, 80, 3)
# Emoji position: (286, 45), Shape: (80, 80, 3)
# Emoji position: (287, 44), Shape: (80, 80, 3)
# Emoji position: (286, 43), Shape: (80, 80, 3)
# Emoji position: (288, 44), Shape: (80, 80, 3)
# Emoji position: (288, 44), Shape: (80, 80, 3)
# Emoji position: (288, 44), Shape: (80, 80, 3)
# Emoji position: (288, 47), Shape: (80, 80, 3)
# Emoji position: (288, 45), Shape: (80, 80, 3)
# Emoji position: (288, 46), Shape: (80, 80, 3)
# Emoji position: (288, 44), Shape: (80, 80, 3)
# Emoji position: (290, 45), Shape: (80, 80, 3)
# Emoji position: (290, 46), Shape: (80, 80, 3)
# Emoji position: (291, 43), Shape: (80, 80, 3)
# Emoji position: (291, 44), Shape: (80, 80, 3)
# Emoji position: (292, 46), Shape: (80, 80, 3)
# Emoji position: (290, 45), Shape: (80, 80, 3)
# Emoji position: (292, 44), Shape: (80, 80, 3)
# Emoji position: (292, 45), Shape: (80, 80, 3)
# Emoji position: (290, 46), Shape: (80, 80, 3)
# Emoji position: (292, 48), Shape: (80, 80, 3)
# Emoji position: (292, 48), Shape: (80, 80, 3)
# Emoji position: (292, 50), Shape: (80, 80, 3)
# Emoji position: (293, 50), Shape: (80, 80, 3)
# Emoji position: (293, 49), Shape: (80, 80, 3)
# Emoji position: (294, 49), Shape: (80, 80, 3)
# Emoji position: (294, 50), Shape: (80, 80, 3)
# Emoji position: (293, 50), Shape: (80, 80, 3)
# Emoji position: (292, 48), Shape: (80, 80, 3)
# Emoji position: (292, 47), Shape: (80, 80, 3)
# Emoji position: (289, 43), Shape: (80, 80, 3)
# Emoji position: (288, 42), Shape: (80, 80, 3)
# Emoji position: (289, 45), Shape: (80, 80, 3)
# Emoji position: (289, 43), Shape: (80, 80, 3)
# Emoji position: (288, 43), Shape: (80, 80, 3)
# Emoji position: (289, 43), Shape: (80, 80, 3)
# Emoji position: (289, 43), Shape: (80, 80, 3)
# Emoji position: (289, 45), Shape: (80, 80, 3)
# Emoji position: (289, 44), Shape: (80, 80, 3)
# Emoji position: (289, 42), Shape: (80, 80, 3)
# Emoji position: (287, 44), Shape: (80, 80, 3)
# Emoji position: (289, 45), Shape: (80, 80, 3)
# Emoji position: (289, 45), Shape: (80, 80, 3)
# Emoji position: (289, 44), Shape: (80, 80, 3)
# Emoji position: (288, 46), Shape: (80, 80, 3)
# Emoji position: (289, 44), Shape: (80, 80, 3)
# Emoji position: (290, 44), Shape: (80, 80, 3)
# Emoji position: (291, 43), Shape: (80, 80, 3)
# Emoji position: (290, 46), Shape: (80, 80, 3)
# Emoji position: (292, 44), Shape: (80, 80, 3)
# Emoji position: (292, 43), Shape: (80, 80, 3)
# Emoji position: (292, 40), Shape: (80, 80, 3)
# Emoji position: (291, 44), Shape: (80, 80, 3)
# Emoji position: (292, 42), Shape: (80, 80, 3)
# Emoji position: (292, 44), Shape: (80, 80, 3)
# Emoji position: (292, 43), Shape: (80, 80, 3)
# Emoji position: (291, 45), Shape: (80, 80, 3)
# Emoji position: (291, 44), Shape: (80, 80, 3)
# Emoji position: (289, 45), Shape: (80, 80, 3)
# Emoji position: (290, 44), Shape: (80, 80, 3)
# Emoji position: (290, 43), Shape: (80, 80, 3)
# Emoji position: (291, 45), Shape: (80, 80, 3)
# Emoji position: (290, 46), Shape: (80, 80, 3)
# Emoji position: (290, 45), Shape: (80, 80, 3)
# Emoji position: (291, 46), Shape: (80, 80, 3)
# Emoji position: (290, 46), Shape: (80, 80, 3)
# Emoji position: (290, 47), Shape: (80, 80, 3)
# Emoji position: (291, 46), Shape: (80, 80, 3)
# Emoji position: (290, 45), Shape: (80, 80, 3)
# Emoji position: (291, 46), Shape: (80, 80, 3)
# Emoji position: (290, 48), Shape: (80, 80, 3)
# Emoji position: (290, 46), Shape: (80, 80, 3)
# Emoji position: (288, 48), Shape: (80, 80, 3)
# Emoji position: (289, 46), Shape: (80, 80, 3)
# Emoji position: (288, 46), Shape: (80, 80, 3)
# Emoji position: (288, 47), Shape: (80, 80, 3)
# Emoji position: (289, 47), Shape: (80, 80, 3)
# Emoji position: (288, 47), Shape: (80, 80, 3)
# Emoji position: (289, 50), Shape: (80, 80, 3)
# Emoji position: (291, 48), Shape: (80, 80, 3)
# Emoji position: (291, 49), Shape: (80, 80, 3)
# Emoji position: (291, 48), Shape: (80, 80, 3)
# Emoji position: (291, 48), Shape: (80, 80, 3)
# Emoji position: (292, 48), Shape: (80, 80, 3)
# Emoji position: (291, 48), Shape: (80, 80, 3)
# Emoji position: (291, 50), Shape: (80, 80, 3)
# Emoji position: (292, 48), Shape: (80, 80, 3)
# Emoji position: (290, 51), Shape: (80, 80, 3)
# Emoji position: (289, 50), Shape: (80, 80, 3)
# Emoji position: (289, 49), Shape: (80, 80, 3)
# Emoji position: (289, 49), Shape: (80, 80, 3)
# Emoji position: (290, 50), Shape: (80, 80, 3)
# Emoji position: (291, 50), Shape: (80, 80, 3)
# Emoji position: (291, 49), Shape: (80, 80, 3)
# Emoji position: (291, 50), Shape: (80, 80, 3)
# Emoji position: (293, 50), Shape: (80, 80, 3)
# Emoji position: (294, 49), Shape: (80, 80, 3)
# Emoji position: (294, 48), Shape: (80, 80, 3)
# Emoji position: (296, 44), Shape: (80, 80, 3)
# Emoji position: (299, 41), Shape: (80, 80, 3)
# Emoji position: (303, 39), Shape: (80, 80, 3)
# Emoji position: (304, 39), Shape: (80, 80, 3)
# Emoji position: (305, 41), Shape: (80, 80, 3)
# Emoji position: (303, 39), Shape: (80, 80, 3)
# Emoji position: (303, 39), Shape: (80, 80, 3)
# Emoji position: (302, 42), Shape: (80, 80, 3)
# Emoji position: (303, 40), Shape: (80, 80, 3)
# Emoji position: (302, 41), Shape: (80, 80, 3)
# Emoji position: (300, 40), Shape: (80, 80, 3)
# Emoji position: (297, 35), Shape: (80, 80, 3)
# Emoji position: (288, 28), Shape: (80, 80, 3)
# Emoji position: (285, 26), Shape: (80, 80, 3)
# Emoji position: (279, 18), Shape: (80, 80, 3)
# Emoji position: (277, 17), Shape: (80, 80, 3)
# Emoji position: (279, 17), Shape: (80, 80, 3)
# Emoji position: (280, 18), Shape: (80, 80, 3)
# Emoji position: (280, 16), Shape: (80, 80, 3)
# Emoji position: (280, 18), Shape: (80, 80, 3)
# Emoji position: (279, 22), Shape: (80, 80, 3)
# Emoji position: (279, 22), Shape: (80, 80, 3)
# Emoji position: (279, 24), Shape: (80, 80, 3)
# Emoji position: (278, 24), Shape: (80, 80, 3)
# Emoji position: (279, 24), Shape: (80, 80, 3)
# Emoji position: (279, 26), Shape: (80, 80, 3)
# Emoji position: (279, 24), Shape: (80, 80, 3)
# Emoji position: (279, 27), Shape: (80, 80, 3)
# Emoji position: (279, 25), Shape: (80, 80, 3)
# Emoji position: (277, 25), Shape: (80, 80, 3)
# Emoji position: (276, 27), Shape: (80, 80, 3)
# Emoji position: (278, 27), Shape: (80, 80, 3)
# Emoji position: (278, 26), Shape: (80, 80, 3)
# Emoji position: (280, 32), Shape: (80, 80, 3)
# Emoji position: (282, 40), Shape: (80, 80, 3)
# Emoji position: (283, 44), Shape: (80, 80, 3)
# Emoji position: (287, 60), Shape: (80, 80, 3)
# Emoji position: (290, 68), Shape: (80, 80, 3)
# Emoji position: (291, 74), Shape: (80, 80, 3)
# Emoji position: (289, 72), Shape: (80, 80, 3)
# Emoji position: (275, 69), Shape: (80, 80, 3)
# Emoji position: (271, 65), Shape: (80, 80, 3)
# Emoji position: (271, 63), Shape: (80, 80, 3)
# Emoji position: (272, 65), Shape: (80, 80, 3)
# Emoji position: (273, 63), Shape: (80, 80, 3)
# Emoji position: (273, 65), Shape: (80, 80, 3)
# Emoji position: (273, 65), Shape: (80, 80, 3)
# Emoji position: (271, 65), Shape: (80, 80, 3)
# Emoji position: (270, 65), Shape: (80, 80, 3)
# Emoji position: (268, 67), Shape: (80, 80, 3)
# Emoji position: (268, 64), Shape: (80, 80, 3)
# Emoji position: (268, 66), Shape: (80, 80, 3)
# Emoji position: (269, 64), Shape: (80, 80, 3)
# Emoji position: (270, 63), Shape: (80, 80, 3)
# Emoji position: (269, 65), Shape: (80, 80, 3)
# Emoji position: (267, 66), Shape: (80, 80, 3)
# Emoji position: (267, 64), Shape: (80, 80, 3)
# Emoji position: (265, 64), Shape: (80, 80, 3)
# Emoji position: (266, 66), Shape: (80, 80, 3)
# Emoji position: (267, 65), Shape: (80, 80, 3)
# Emoji position: (267, 65), Shape: (80, 80, 3)
# Emoji position: (269, 67), Shape: (80, 80, 3)
# Emoji position: (268, 67), Shape: (80, 80, 3)
# Emoji position: (268, 66), Shape: (80, 80, 3)
# Emoji position: (268, 66), Shape: (80, 80, 3)
# Emoji position: (268, 67), Shape: (80, 80, 3)
# Emoji position: (266, 65), Shape: (80, 80, 3)
# Emoji position: (267, 67), Shape: (80, 80, 3)
# Emoji position: (266, 64), Shape: (80, 80, 3)
# Emoji position: (266, 66), Shape: (80, 80, 3)
# Emoji position: (267, 67), Shape: (80, 80, 3)
# Emoji position: (269, 66), Shape: (80, 80, 3)
# Emoji position: (270, 66), Shape: (80, 80, 3)
# Emoji position: (270, 67), Shape: (80, 80, 3)
# Emoji position: (270, 67), Shape: (80, 80, 3)
# Emoji position: (271, 67), Shape: (80, 80, 3)
# Emoji position: (270, 67), Shape: (80, 80, 3)
# Emoji position: (270, 67), Shape: (80, 80, 3)
# Emoji position: (269, 66), Shape: (80, 80, 3)
# Emoji position: (269, 65), Shape: (80, 80, 3)
# Emoji position: (269, 64), Shape: (80, 80, 3)
# Emoji position: (268, 64), Shape: (80, 80, 3)
# Emoji position: (269, 66), Shape: (80, 80, 3)
# Emoji position: (269, 64), Shape: (80, 80, 3)
# Emoji position: (269, 67), Shape: (80, 80, 3)
# Emoji position: (270, 66), Shape: (80, 80, 3)
# Emoji position: (269, 65), Shape: (80, 80, 3)
# Emoji position: (270, 68), Shape: (80, 80, 3)
# Emoji position: (271, 67), Shape: (80, 80, 3)
# Emoji position: (270, 66), Shape: (80, 80, 3)
# Emoji position: (272, 66), Shape: (80, 80, 3)
# Emoji position: (272, 65), Shape: (80, 80, 3)
# Emoji position: (271, 66), Shape: (80, 80, 3)
# Emoji position: (269, 65), Shape: (80, 80, 3)
# Emoji position: (270, 67), Shape: (80, 80, 3)
# Emoji position: (269, 67), Shape: (80, 80, 3)
# Emoji position: (270, 64), Shape: (80, 80, 3)
# Emoji position: (270, 66), Shape: (80, 80, 3)
# Emoji position: (271, 66), Shape: (80, 80, 3)
# Emoji position: (272, 67), Shape: (80, 80, 3)
# Emoji position: (271, 65), Shape: (80, 80, 3)
# Emoji position: (272, 65), Shape: (80, 80, 3)
# Emoji position: (272, 68), Shape: (80, 80, 3)
# Emoji position: (273, 67), Shape: (80, 80, 3)
# Emoji position: (272, 66), Shape: (80, 80, 3)
# Emoji position: (272, 67), Shape: (80, 80, 3)
# Emoji position: (272, 67), Shape: (80, 80, 3)
# Emoji position: (272, 65), Shape: (80, 80, 3)
# Emoji position: (272, 65), Shape: (80, 80, 3)
# Emoji position: (271, 65), Shape: (80, 80, 3)
# Emoji position: (271, 66), Shape: (80, 80, 3)
# Emoji position: (271, 64), Shape: (80, 80, 3)
# Emoji position: (271, 65), Shape: (80, 80, 3)
# Emoji position: (269, 65), Shape: (80, 80, 3)
# Emoji position: (267, 61), Shape: (80, 80, 3)
# Emoji position: (265, 59), Shape: (80, 80, 3)
# Emoji position: (265, 58), Shape: (80, 80, 3)
# Emoji position: (265, 61), Shape: (80, 80, 3)
# Emoji position: (267, 61), Shape: (80, 80, 3)
# Emoji position: (269, 58), Shape: (80, 80, 3)
# Emoji position: (269, 60), Shape: (80, 80, 3)
# Emoji position: (269, 61), Shape: (80, 80, 3)
# Emoji position: (268, 59), Shape: (80, 80, 3)
# Emoji position: (268, 63), Shape: (80, 80, 3)
# Emoji position: (269, 65), Shape: (80, 80, 3)
# Emoji position: (268, 62), Shape: (80, 80, 3)
# Emoji position: (267, 63), Shape: (80, 80, 3)
# Emoji position: (268, 62), Shape: (80, 80, 3)
# Emoji position: (266, 63), Shape: (80, 80, 3)
# Emoji position: (268, 63), Shape: (80, 80, 3)
# Emoji position: (266, 62), Shape: (80, 80, 3)
# Emoji position: (267, 63), Shape: (80, 80, 3)
# Emoji position: (266, 62), Shape: (80, 80, 3)
# Emoji position: (267, 63), Shape: (80, 80, 3)
# Emoji position: (268, 65), Shape: (80, 80, 3)
# Emoji position: (268, 61), Shape: (80, 80, 3)
# Emoji position: (267, 62), Shape: (80, 80, 3)
# Emoji position: (267, 63), Shape: (80, 80, 3)
# Emoji position: (267, 62), Shape: (80, 80, 3)

# %% [markdown]
# # FOR MULTIPLE USERS INFRONT OF CCCTV. USE THIS CODE. THIS WORKS ( MULTIPLE EMOTION DETECTION)

# %%
import cv2
from fer import FER

# Initialize emotion detector
emotion_detector = FER()

# Load emoji images separately
happy_emoji = cv2.imread(r'E:\jupyter_notebook\Pictures\happy2.png', cv2.IMREAD_UNCHANGED)
sad_emoji = cv2.imread(r'E:\jupyter_notebook\Pictures\sad2png.png', cv2.IMREAD_UNCHANGED)
angry_emoji = cv2.imread(r'E:\jupyter_notebook\Pictures\angry2.png', cv2.IMREAD_UNCHANGED)
neutral_emoji = cv2.imread(r'E:\jupyter_notebook\Pictures\neutral.png', cv2.IMREAD_UNCHANGED)

# Function to resize emoji if loaded
def resize_emoji(emoji, size):
    if emoji is not None:
        return cv2.resize(emoji, size, interpolation=cv2.INTER_AREA)
    else:
        print("Failed to load emoji, cannot resize.")
        return None

# Resize emojis to a smaller size (e.g., 50x50 pixels)
emoji_size = (50, 50)
happy_emoji = resize_emoji(happy_emoji, emoji_size)
sad_emoji = resize_emoji(sad_emoji, emoji_size)
angry_emoji = resize_emoji(angry_emoji, emoji_size)
neutral_emoji = resize_emoji(neutral_emoji, emoji_size)

# Start video capture
cap = cv2.VideoCapture(0)

# Get the width and height of the video capture
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Define the codec and create VideoWriter object
fourcc = cv2.VideoWriter_fourcc(*'XVID')
output_filename = 'output_video.avi'
out = cv2.VideoWriter(output_filename, fourcc, 20.0, (frame_width, frame_height))

# Set the probability threshold
probability_threshold = 0.5

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Detect emotions
    emotions = emotion_detector.detect_emotions(frame)
    if emotions:
        for emotion_data in emotions:
            emotion_dict = emotion_data['emotions']
            total_prob = sum(emotion_dict.values())
            
            if total_prob > 0:
                normalized_emotions = {emotion: prob / total_prob for emotion, prob in emotion_dict.items()}
                
                top_emotion, top_probability = max(normalized_emotions.items(), key=lambda item: item[1])

                if top_probability > probability_threshold:
                    x, y, w, h = emotion_data['box']
                    cv2.rectangle(frame, (x, y), (x + w, y + h), (255, 0, 0), 2)

                    emotion_text = f"{top_emotion}: {top_probability:.2f}"
                    cv2.putText(frame, emotion_text, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2, cv2.LINE_AA)

                    # Determine which emoji to display
                    if top_emotion == 'happy':
                        emoji_img = happy_emoji
                    elif top_emotion == 'sad':
                        emoji_img = sad_emoji
                    elif top_emotion == 'angry':
                        emoji_img = angry_emoji
                    elif top_emotion == 'neutral':
                        emoji_img = neutral_emoji
                    else:
                        emoji_img = None  # No valid emoji

                    if emoji_img is not None:
                        emoji_height, emoji_width = emoji_img.shape[:2]
                        emoji_x = x + w // 2 - emoji_width // 2
                        emoji_y = y - emoji_height - 10

                        if emoji_y > 0 and emoji_x >= 0:  # Ensure emoji fits in frame
                            if emoji_img.shape[2] == 4:  # PNG with alpha channel
                                emoji_mask = emoji_img[:, :, 3] / 255.0
                                for c in range(0, 3):
                                    frame[emoji_y:emoji_y + emoji_height, emoji_x:emoji_x + emoji_width, c] = (
                                        emoji_mask * emoji_img[:, :, c] +
                                        (1 - emoji_mask) * frame[emoji_y:emoji_y + emoji_height, emoji_x:emoji_x + emoji_width, c]
                                    )
                            else:  # JPG without alpha channel
                                frame[emoji_y:emoji_y + emoji_height, emoji_x:emoji_x + emoji_width] = emoji_img[:emoji_height, :emoji_width]

    # Write the frame to the video file
    out.write(frame)

    cv2.imshow('Emotion Detection', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release everything
cap.release()
out.release()
cv2.destroyAllWindows()
